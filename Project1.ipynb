# %% [markdown]
# # Mashable (www.mashable.com) --is a global, multi-platform media and entertainment company. Powered by its own proprietary technology, Mashable is the go-to source for tech, digital culture and entertainment content for its dedicated and influential audience around the globe.
# Just like any other media company its success depends on the popularity of articles.  And one of the key metrics to measure popularity is no. of shares done on article.
# Over period of few years Mashable has collected data on around 40,000 articles.
# You as ML expert have to do analysis and modeling to predict number of shares of an article
# given the input parameters.

# %%
import pandas as pd

df = pd.read_csv("OnlineNewsPopularity.csv")
df.head()
# Out:
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...      731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...      731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...      731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...      731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/      731.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs   ...    \
# 0                  0.815385        4.0             2.0       1.0   ...
# 1                  0.791946        3.0             1.0       1.0   ...
# 2                  0.663866        3.0             1.0       1.0   ...
# 3                  0.665635        9.0             0.0       1.0   ...
# 4                  0.540890       19.0            19.0      20.0   ...
#
#    min_positive_polarity  max_positive_polarity  avg_negative_polarity  \
# 0               0.100000                    0.7              -0.350000
# 1               0.033333                    0.7              -0.118750
# 2               0.100000                    1.0              -0.466667
# 3               0.136364                    0.8              -0.369697
# 4               0.033333                    1.0              -0.220192
#
#    min_negative_polarity  max_negative_polarity  title_subjectivity  \
# 0                 -0.600              -0.200000            0.500000
# 1                 -0.125              -0.100000            0.000000
# 2                 -0.800              -0.133333            0.000000
# 3                 -0.600              -0.166667            0.000000
# 4                 -0.500              -0.050000            0.454545
#
#    title_sentiment_polarity  abs_title_subjectivity  \
# 0                 -0.187500                0.000000
# 1                  0.000000                0.500000
# 2                  0.000000                0.500000
# 3                  0.000000                0.500000
# 4                  0.136364                0.045455
#
#    abs_title_sentiment_polarity  shares
# 0                      0.187500     593
# 1                      0.000000     711
# 2                      0.000000    1500
# 3                      0.000000    1200
# 4                      0.136364     505
#
# [5 rows x 61 columns]

# %%
#Normalize shares values
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit(df['shares'])
le.classes_
df['shares'] = le.transform(df['shares']) 
print(df.head(5))
# Out:
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...      731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...      731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...      731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...      731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/      731.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs   ...    \
# 0                  0.815385        4.0             2.0       1.0   ...
# 1                  0.791946        3.0             1.0       1.0   ...
# 2                  0.663866        3.0             1.0       1.0   ...
# 3                  0.665635        9.0             0.0       1.0   ...
# 4                  0.540890       19.0            19.0      20.0   ...
#
#    min_positive_polarity  max_positive_polarity  avg_negative_polarity  \
# 0               0.100000                    0.7              -0.350000
# 1               0.033333                    0.7              -0.118750
# 2               0.100000                    1.0              -0.466667
# 3               0.136364                    0.8              -0.369697
# 4               0.033333                    1.0              -0.220192
#
#    min_negative_polarity  max_negative_polarity  title_subjectivity  \
# 0                 -0.600              -0.200000            0.500000
# 1                 -0.125              -0.100000            0.000000
# 2                 -0.800              -0.133333            0.000000
# 3                 -0.600              -0.166667            0.000000
# 4                 -0.500              -0.050000            0.454545
#
#    title_sentiment_polarity  abs_title_subjectivity  \
# 0                 -0.187500                0.000000
# 1                  0.000000                0.500000
# 2                  0.000000                0.500000
# 3                  0.000000                0.500000
# 4                  0.136364                0.045455
#
#    abs_title_sentiment_polarity  shares
# 0                      0.187500     448
# 1                      0.000000     566
# 2                      0.000000     860
# 3                      0.000000     857
# 4                      0.136364     360
#
# [5 rows x 61 columns]

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(df.iloc[:,2:], df['shares'], test_size=0.20, random_state=5)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA()
lda.fit(train_x, train_y)
train_x = lda.transform(train_x)
test_x = lda.transform(test_x)
# Out:
# D:\Anaconda_Installation_Dir\lib\site-packages\sklearn\discriminant_analysis.py:442: UserWarning: The priors do not sum to 1. Renormalizing
#   UserWarning)
# D:\Anaconda_Installation_Dir\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC,NuSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier

from sklearn import metrics

classifiers = [KNeighborsClassifier(3), DecisionTreeClassifier(), RandomForestClassifier(),
               GaussianNB(),
               AdaBoostClassifier(n_estimators=100,random_state=7)]

for clf in classifiers:
    name = clf.__class__.__name__
    print("="*30)
    print(name)
    clf.fit(train_x,train_y)
    pred_y = clf.predict(test_x)
    #calculate accuracy
    calc_accuracy = metrics.accuracy_score(test_y,pred_y)
    print("Accuracy of model::", calc_accuracy)
# Out:
# D:\Anaconda_Installation_Dir\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# ==============================
# KNeighborsClassifier
# Accuracy of model:: 0.0183713793248413
# ==============================
# DecisionTreeClassifier
# Accuracy of model:: 0.019590532643881112
# ==============================
# RandomForestClassifier
# Accuracy of model:: 0.022995753983268172
# ==============================
# GaussianNB
# Accuracy of model:: 0.006095766595199058
# ==============================
# AdaBoostClassifier
# Accuracy of model:: 0.056921848068272586
# ==============================
# SVC
