# %% [markdown]
# # Load the kinematics dataset as measured on mobile sensors from the file “run_or_walk.csv”. List out the columns in the dataset

# %%
import pandas as pd
df = pd.read_csv("run_or_walk.csv")
df.head()
# Out:
#         date                time username  wrist  activity  acceleration_x  \
# 0  2017-6-30  13:51:15:847724020   viktor      0         0          0.2650
# 1  2017-6-30  13:51:16:246945023   viktor      0         0          0.6722
# 2  2017-6-30  13:51:16:446233987   viktor      0         0          0.4399
# 3  2017-6-30  13:51:16:646117985   viktor      0         0          0.3031
# 4  2017-6-30  13:51:16:846738994   viktor      0         0          0.4814
#
#    acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# 1         -1.1233         -0.2344 -0.1757  0.0208  0.1269
# 2         -1.4817          0.0722 -0.9105  0.1063 -2.4367
# 3         -0.8125          0.0888  0.1199 -0.4099 -2.9336
# 4         -0.9312          0.0359  0.0527  0.4379  2.4922

# %% [markdown]
# # Let the target variable ‘y’ be the activity and assign all the columns after it to ‘x’

# %%
from sklearn.model_selection import train_test_split

print(df.iloc[:,5:])
train_x, test_x, train_y, test_y = train_test_split(df.iloc[:,5:], df['activity'], test_size=0.20, random_state=5)
# Out:
#        acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0              0.2650         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# 1              0.6722         -1.1233         -0.2344 -0.1757  0.0208  0.1269
# 2              0.4399         -1.4817          0.0722 -0.9105  0.1063 -2.4367
# 3              0.3031         -0.8125          0.0888  0.1199 -0.4099 -2.9336
# 4              0.4814         -0.9312          0.0359  0.0527  0.4379  2.4922
# 5              0.4044         -0.8056         -0.0956  0.6925 -0.2179  2.5750
# 6              0.6320         -1.1290         -0.2982  0.0548 -0.1896  0.4473
# 7              0.6670         -1.3503         -0.0880 -0.8094 -0.7938 -1.4348
# 8              0.2704         -0.8633          0.1293 -0.4173 -0.1904 -2.6759
# 9              0.4690         -1.0740          0.0219  0.0388  1.1491  1.6982
# 10             0.2985         -0.7172         -0.0693  0.2326  0.4321  2.1009
# ...

# %% [markdown]
# # Using Scikit-learn fit a Gaussian Naive Bayes model and observe the accuracy.Generate a classification report using scikitlearn.

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

gnb = GaussianNB()
pred_y_gnb = gnb.fit(train_x, train_y)
pred_y = pred_y_gnb.predict(test_x)
print("Accuracy::", metrics.accuracy_score(test_y, pred_y))
# Out:
# Accuracy:: 0.9565978101365843

# %% [markdown]
# # Repeat the model once using only the acceleration values as predictors and then using only the gyro values as predictors. Comment on the difference in accuracy between both the models.

# %%
#with only acc
print(df.iloc[:,5:8])
train_x_acc, test_x_acc, train_y_acc, test_y_acc = train_test_split(df.iloc[:,5:7], df['activity'], test_size=0.20, random_state=5)
gnb_acc = GaussianNB()
pred_y_gnb_acc = gnb_acc.fit(train_x_acc, train_y_acc)
pred_y_acc = pred_y_gnb_acc.predict(test_x_acc)
print("Accuracy::", metrics.accuracy_score(test_y_acc, pred_y_acc))

#with only gyro
print(df.iloc[:,8:11])
train_x_gyro, test_x_gyro, train_y_gyro, test_y_gyro = train_test_split(df.iloc[:,7:9], df['activity'], test_size=0.20, random_state=5)
gnb_gyro = GaussianNB()
pred_y_gnb_gyro = gnb_acc.fit(train_x_gyro, train_y_gyro)
pred_y_gyro = pred_y_gnb_gyro.predict(test_x_gyro)
print("Accuracy::", metrics.accuracy_score(test_y_gyro, pred_y_gyro))
# Out:
#        acceleration_x  acceleration_y  acceleration_z
# 0              0.2650         -0.7814         -0.0076
# 1              0.6722         -1.1233         -0.2344
# 2              0.4399         -1.4817          0.0722
# 3              0.3031         -0.8125          0.0888
# 4              0.4814         -0.9312          0.0359
# 5              0.4044         -0.8056         -0.0956
# 6              0.6320         -1.1290         -0.2982
# 7              0.6670         -1.3503         -0.0880
# 8              0.2704         -0.8633          0.1293
# 9              0.4690         -1.0740          0.0219
# 10             0.2985         -0.7172         -0.0693
# 11             0.6364         -1.0452         -0.2400
# 12             0.5683         -1.2486         -0.1310
# 13             0.2911         -0.7748          0.0163
# 14             0.4477         -1.1574         -0.0172
# 15             0.2424         -0.7421         -0.0549
# ...
