# %% [markdown]
# # Load the data from “cereal.csv” and plot histograms of sugar and vitamin content across different cereals

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv("cereal.csv")
df
# Out:
#                                       name mfr type  calories  protein  fat  \
# 0                                100% Bran   N    C        70        4    1
# 1                        100% Natural Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran with Extra Fiber   K    C        50        4    0
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 7                                  Basic 4   G    C       130        3    2
# 8                                Bran Chex   R    C        90        2    1
# 9                              Bran Flakes   P    C        90        3    0
# 10                            Cap'n'Crunch   Q    C       120        1    2
# ...

# %%
sugarsdf = df['sugars']
num_bins = 11
print(num_bins)
n, bins, patches = plt.hist(sugarsdf, num_bins, facecolor='blue', alpha=0.5)
plt.show()
# Out:
# 11

# %%
vitaminsdf = df['vitamins']
num_bins = 2
n, bins, patches = plt.hist(vitaminsdf, num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %% [markdown]
# # The names of the manufactures are coded using alphabets, create a new column with their fullname using the below mapping.

# %%
manufacturer_codes = {'N': 'Nabisco',  'Q': 'Quaker Oats',  'K': 'Kelloggs',  'R': 'Raslston Purina',  'G': 'General Mills' ,  'P' :'Post' ,  'A':'American Home Foods Products' }
df['fullname'] = df['mfr'].map(manufacturer_codes)
df
# Out:
#                                       name mfr type  calories  protein  fat  \
# 0                                100% Bran   N    C        70        4    1
# 1                        100% Natural Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran with Extra Fiber   K    C        50        4    0
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 7                                  Basic 4   G    C       130        3    2
# 8                                Bran Chex   R    C        90        2    1
# 9                              Bran Flakes   P    C        90        3    0
# 10                            Cap'n'Crunch   Q    C       120        1    2
# ...

# %% [markdown]
# # Create a bar plot where each manufacturer is on the y axis and the height of the bars depict the number of cereals manufactured by them.
# [Hint: Try using countplot this time or bar method of pyplot]

# %%
import seaborn as sns
# Using Countplot
sns.countplot(df.mfr)  
plt.show()

# %% [markdown]
# # Extract the rating as your target variable ‘y’ and all numerical parameters as your predictors ‘x’. Separate 25% of your data as test set.

# %%
x = df.iloc[:,3:15]
#print(x)

y = df['rating']
#print(y)

# %%
#calculating co-relation
import seaborn as sns

#creating co-relation matrix
corelations = df.corr()
sns.heatmap(corelations, square=True, cmap='YlGnBu')
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %%
#seperate 25% of test data
from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 5)
# Out:
# D:\Anaconda_Installation_Dir\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# # Fit a linear regression module and measure the mean squared error on test dataset

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
model = lm.fit(x_train, y_train)

# %%
pred_y = lm.predict(x_test)

# %%
print("Mean squared error: %.2f" % mean_squared_error(y_test, pred_y))

print("Variance score: %.2f" % r2_score(y_test, pred_y))
# Out:
# Mean squared error: 0.00
# Variance score: 1.00

# %%
#co-efficients
print("Estimated intercept co-efficients: \n", lm.intercept_)
print("Number of feature co-efficients: \n", len(lm.coef_))
print("Feature co-efficients: \n", lm.coef_)
# Out:
# Estimated intercept co-efficients:
#  54.92718381198523
# Number of feature co-efficients:
#  12
# Feature co-efficients:
#  [-2.22724166e-01  3.27317387e+00 -1.69140801e+00 -5.44927023e-02
#   3.44347976e+00  1.09245095e+00 -7.24895157e-01 -3.39933504e-02
#  -5.12119698e-02  9.84742115e-09  2.83740456e-07  2.03959862e-07]
